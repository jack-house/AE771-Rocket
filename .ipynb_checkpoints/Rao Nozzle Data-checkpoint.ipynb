# %%
#Python Initiation
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline, BSpline
import pandas as pd
import ipywidgets as widgets
import time
import math
from IPython.display import display
from sympy.solvers import solve


#Graph Formatting
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 14
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
Res=100 #Resoultion of the calulations

#Graph Font Edit
font = {'family':'Times New Roman',
        'weight' : 'bold',
        'size'   : 22}
matplotlib.rc('font', **font)

# %%
#Rao Nozzle Data

#SSME Data
Dt=10.3  #Throat Diameter | in
Rt=Dt/2  #Throat Radius | in
De=90.7  #Exit Diameter | in
Re=De/2  #Exit Radius |in
Ln=121   #Nozzle Length | in
ε=77.5   #Area Radio | unitless
θn=42    #Nozzle Throat Angle | Degrees
θe=5     #Nozzle Exit Back Angle | Degree

#Calculations
Ln_cone=((np.sqrt(ε)-1)*Rt)/(np.tan(15))  #Length of Conical Nozzle | in
Re=np.sqrt(ε)*Rt                          #Radius of Nozzle Exit | in
Ln_bell=0.8*Ln_cone
θen=np.arange(-135,-90,0.01)              #Throat Entrant Angle | Degrees
θ2=np.arange(-90,(θn-90),0.01)            #Throat Exit Angle | Degrees
t=np.arange(0,1,0.01)                     #Variation of Bezier Curve
Ex=Ln_cone                                #X-Coordinates defined from Length of Cone | in 
Ey=Re                                     #Y-Coordinates defined from Radius of Exit | in
Nx=0.382*Rt*cos(θn-90)                    #X-Coordinates of inflection point | in
Ny=0.382*Rt*sin(θn-90)+0.382*Rt+Rt        #Y-Coordinates of inflection point | in
m1=np.tan(θn)                             #Gradient
m2=np.tan(θe)                             #Gradient
C1=Ny-m1*Nx                               #Intercept
C2=Ey-m2*Ex                               #Intercept
Qx=(C2-C1)/(m1-m2)                        #X-intercept @ pt Q | in
Qy=((m1*C2)-(m2*C1))/(m1-m2)              #Y-intercept @ pt Q | in


#Plotting Points

#Throat
xen=1.5*Rt*cos(θen)                       #X-Coordinates of Throat Entrant
yen=1.5*Rt*sin(θen)+1.5*Rt+Rt             #Y-Coordinates of Throat Entrant

x2=0.382*Rt*cos(θ2)                       #X-Coordinates of Throat Exit
y2=0.382*Rt*sin(θ2)+0.382*Rt+Rt           #Y-Coordinates of Throat Exit

#Bell
xt=(1-t)**2*Nx+2*(1-t)*t+t**2*Ex          #X-Coordinates of Bell Curve
yt=(1-t)**2*Ny+2*(1-t)*t+t**2*Ey          #Y-Coordinate of Bell Curve


#Plot
